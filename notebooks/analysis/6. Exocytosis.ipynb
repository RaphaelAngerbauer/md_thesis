# %% [markdown]
# # Lab Book
# ## 6. Inhibition of Autophagy increases Exocytosis of a-Synuclein
# ### WB
# ---
# #### Protocol
# **D0 - Seeding**
# - Seed 300.000 HeLa cells per well in 6 Well (diluted in 2mL DMEM)
# - Layout:
#     - 2 Wells per row per condition:
#         Conditions: X, TP, FY
#
# **D1 - Transfection**
# - Change Media beforehand
# - Transfect in a 1:2 manner (Plasmid1:Plasmid2)
# - 0.1µg total amount of Plasmid per Well
# - Conditions:
#     - X: P1 = aSyn(WT)-GFP, P2 = pcDNA
#     - TP: P1 = aSyn(WT)-GFP, P2 = TP-Linker-Protein
#     - FY: P1 = aSyn(WT)-GFP, P2 = FY-Linker-Protein
#
# - Change Media 4h after Transfection
# - Treatments:
#     - Ctrl: DMEM
#     - CQ: 20µM Chloroquine
#     - BAF: 200nM Bafilomycin
#
# **D2 - TCA-Precipitation**
#
# TBD
#
# **D3 - Western Blot**
# - Prepare 15% Polyacrylamide Gel
# - Boil samples @97°C for 60s
# - Add SizeMarker
# - Add appropriate amounts of sample
# - Run at 80V for 20mins
# - Run as 130V until 10kD Marker at bottom
# - Take out Gel and put into Transfer Buffer
# - Transfer:
#     - Put 5 Whattman Paper (WP) + Nitrocellulose membrane + Gel + 5 WP into Transfer-Machine
#     - Run for 40mins
#     - Take out membrane and out into TBST
#     - Ponceau stain:
#         - Stain with Ponceau S
#         - Put back staining liquid into bottle
#         - wash multiple times with H2O
#         - Destain with TBST for 5mins
# - Blocking:
#     - Put Membrane into 5% Milk in TBST for 1h
# - 1°AB - aSyn:
#     - Put Anti-aSyn-AB into 5% BSA in TBST
#     - Incubate Membrane in solution @ 4°C overnight
#
# **D4 - Imaging - aSyn**
# - Wash in TBST for 3x for 5mins
# - 2°AB - GFP:
#     - Put Anti-Mouse-AB into 5% Milk in TBST
#     - Incubate Membrane in solution @ RT for 1h
# - Wash in TBST for 3x for 5mins
# - Add ECL to Membrane
# - Image immediately

# %%
import pathophys as pp
spec = "6"
df = pp.get_df_wb(spec, True)
# Out:
# E:\Raphael\Data\6. Inhibition Plasmid-mediated degradation increases exocytosis of GFP-tagged α-Synuclein\WB\1
# E:\Raphael\Data\6. Inhibition Plasmid-mediated degradation increases exocytosis of GFP-tagged α-Synuclein\WB\2
# E:\Raphael\Data\6. Inhibition Plasmid-mediated degradation increases exocytosis of GFP-tagged α-Synuclein\WB\3
# BAF
# 0.9288327615996655
# 16779.083
# BAF
# 0.7646701166901585
# 13846.669
# BAF
# 0.5582624700004755
# 15920.669
# BAF
# 0.729343636132334
# 22237.711
# BAF
# 0.9331172488878439
# 25054.711
# BAF
# 0.8119214771210859
# 25206.004
# BAF
# 0.6561537084656135
# 24883.418
# BAF
# 0.9227127525786629
# 25377.589
# BAF
# 15     1.113222        1.133480        1.000000           1.000000   2
# 16     3.089546        0.860475        1.963731           0.767287   2
# 17     1.350083        1.673748        1.554148           0.921936   2
# 18     1.000000        1.000000        1.000000           1.000000   3
# 19     1.000000        1.000000        0.724063           0.968824   3
# 20     1.000000        1.000000        1.257782           0.615993   3
# 21     1.406245        1.019859        1.000000           1.000000   3
# 22     1.325375        1.300546        0.682424           1.235465   3
# 23     1.266433        1.481126        1.132731           0.894597   3
# 24     1.174005        1.062855        1.000000           1.000000   3
# 25     3.090043        0.883068        1.905771           0.804943   3
# 26     1.474558        1.753728        1.579781           1.016398   3

# %%
y = "aSyn_norm_DMSO"
x = "Group2"
z = "Group1"

pp.plottrieswb(df,x,y,z)
# Out:
# ['1' '2' '3']
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 0    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 1    1.20786
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 2    1.157431
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 3    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 4    1.332576
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 5    1.161098
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 6    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 7    2.388912
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 8    2.005796
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 9    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 10    0.70757
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 11    1.281485
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 12    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 13    0.682335
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 14    1.172072
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 15    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 16    1.963731
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 17    1.554148
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 18    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 19    0.724063
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 20    1.257782
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 21    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 22    0.682424
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 23    1.132731
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 1
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 24    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 25    1.905771
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 26    1.579781
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# n = 3
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 0     1.0
# 9     1.0
# 18    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 1     1.207860
# 10    0.707570
# 19    0.724063
# Name: aSyn_norm_DMSO, dtype: float64 0.3216036063492411 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 2     1.157431
# 11    1.281485
# 20    1.257782
# Name: aSyn_norm_DMSO, dtype: float64 0.07452221936878042 2 0.8
# n = 3
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 3     1.0
# 12    1.0
# 21    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 4     1.332576
# 13    0.682335
# 22    0.682424
# Name: aSyn_norm_DMSO, dtype: float64 0.42479551775401697 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 5     1.161098
# 14    1.172072
# 23    1.132731
# Name: aSyn_norm_DMSO, dtype: float64 0.02297307912205102 2 0.8
# n = 3
# AxesSubplot(0.125,0.11;0.775x0.77) DMSO 6     1.0
# 15    1.0
# 24    1.0
# Name: aSyn_norm_DMSO, dtype: float64 0.0 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) CQ 7     2.388912
# 16    1.963731
# 25    1.905771
# Name: aSyn_norm_DMSO, dtype: float64 0.29852510437645896 2 0.8
# AxesSubplot(0.125,0.11;0.775x0.77) BAF 8     2.005796
# 17    1.554148
# 26    1.579781
# Name: aSyn_norm_DMSO, dtype: float64 0.28707004571017175 2 0.8

# %%
figsize = [14*pp.cm,7*pp.cm]
pp.createfigure(spec, figsize)
# Out:
# {0: ['WB_0']}
# {0: ['WB_0']}
# 0
# Ponceau
# {'GFP': '28', 'aSyn': '49', 'b-Actin': '42', 'LC3-I': '16', 'LC3-II': '14', 'p62': '62', 'Ponceau': '??'}
# ??
# aSyn
# {'GFP': '28', 'aSyn': '49', 'b-Actin': '42', 'LC3-I': '16', 'LC3-II': '14', 'p62': '62', 'Ponceau': '??'}
# 49

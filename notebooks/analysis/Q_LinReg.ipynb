# %%
import pathophys as pp
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from sklearn.linear_model import LinearRegression

basedir = pp.getparentdir("Y")
folder = os.path.join(basedir, "Curve")
df = pd.read_csv(os.path.join(folder,"Spark.csv"), sep =";")
df.head()
plt.plot(df["GFP"],df["Flurescence"], 'o', label='original data')
data = np.array(df["GFP"],df["Flurescence"])
regressor = LinearRegression(fit_intercept=False)
res = regressor.fit(data)
#x = np.arange(df["GFP"].max())
x = df["GFP"].values
params = regressor.get_params()
print(params)
#print(res.intercept)plt.plot(x, res.intercept + res.slope*x, 'r', label='fitted line')
#plt.plot((32-res.intercept)/res.slope,32,'og')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9344\2289511919.py in <cell line: 15>()
#      13 data = np.array(df["GFP"],df["Flurescence"])
#      14 regressor = LinearRegression(fit_intercept=False)
# ---> 15 res = regressor.fit(data)
#      16 #x = np.arange(df["GFP"].max())
#      17 x = df["GFP"].values
#
# TypeError: fit() missing 1 required positional argument: 'y'
